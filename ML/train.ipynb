# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import pickle
# %matplotlib inline

# %%
faculties = pd.read_csv('./datasets/appraisal_dataset_v2_augmented.csv')
X = faculties.iloc[:, :-1].values
y = faculties.iloc[:,5]

faculties.head()
# Out:
#    Student Review  Experience (years)  No. of Research Papers Published  \
# 0        5.749348           11.940353                          6.688979
# 1        4.477457            9.092380                          7.615433
# 2        3.976247            9.719228                          8.589518
# 3        4.935652            9.224000                          7.391379
# 4        4.506391            9.726807                          7.204741
#
#    Seminars Taken    Events  Attendance (%)  Appraisal (%)
# 0        5.976812  3.227852       85.290360       8.012325
# 1        6.109734  5.239973       85.344467       7.944750
# 2        5.851566  3.642474       85.404490       9.200791
# 3        4.491432  4.334186       88.098005       9.126268
# 4        5.493876  4.405328       87.821681       8.701315

# %%
sns.heatmap(faculties.corr(), annot=True)
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [85.23888135 85.38063226 85.38094155 ... 86.11358343 86.4082896
#  85.61021408]

# %%
r2_score(y_test, y_pred)
# Out:
# 1.0

# %%
# Saving The Model
with open('./models/model_v2.pkl', 'wb') as f:
    pickle.dump(model, f)
